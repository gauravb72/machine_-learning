# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("E:\\dtaa\\bird_strikes.csv",encoding='latin1')
df
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane   DALLAS or FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# ...          ...            ...                              ...          ...
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680         others                          unknown       others
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
# ...

# %%
df.isnull().sum()
# Out:
# Record ID                                    0
# Aircraft: Type                               0
# Airport: Name                                0
# Altitude bin                                 0
# Aircraft: Make/Model                         0
# Wildlife: Number struck                      0
# Wildlife: Number Struck Actual               0
# Effect: Impact to flight                     0
# FlightDate                                   0
# Effect: Indicated Damage                     0
# Aircraft: Number of engines?                 0
# Aircraft: Airline/Operator                   0
# Origin State                               449
# When: Phase of flight                        0
# Conditions: Precipitation                    0
# Remains of wildlife collected?               0
# Remains of wildlife sent to Smithsonian      0
# Remarks                                      0
# Wildlife: Size                               0
# Conditions: Sky                              0
# ...

# %%
df1=df.fillna(method='ffill')
df1
# Out:
#        Record ID Aircraft: Type                    Airport: Name Altitude bin  \
# 0         202152       Airplane                     LAGUARDIA NY    > 1000 ft
# 1         208159       Airplane   DALLAS or FORT WORTH INTL ARPT    < 1000 ft
# 2         207601       Airplane                LAKEFRONT AIRPORT    < 1000 ft
# 3         215953       Airplane              SEATTLE-TACOMA INTL    < 1000 ft
# 4         219878       Airplane                     NORFOLK INTL    < 1000 ft
# ...          ...            ...                              ...          ...
# 25553     321151       Airplane                REDDING MUNICIPAL    > 1000 ft
# 25554     319677       Airplane                     ORLANDO INTL    < 1000 ft
# 25555     319680         others                          unknown       others
# 25556     319679       Airplane  DETROIT METRO WAYNE COUNTY ARPT    < 1000 ft
# 25557     319593       Airplane     ABRAHAM LINCOLN CAPITAL ARPT    < 1000 ft
#
# ...

# %%
df1.isnull().sum()
# Out:
# Record ID                                  0
# Aircraft: Type                             0
# Airport: Name                              0
# Altitude bin                               0
# Aircraft: Make/Model                       0
# Wildlife: Number struck                    0
# Wildlife: Number Struck Actual             0
# Effect: Impact to flight                   0
# FlightDate                                 0
# Effect: Indicated Damage                   0
# Aircraft: Number of engines?               0
# Aircraft: Airline/Operator                 0
# Origin State                               0
# When: Phase of flight                      0
# Conditions: Precipitation                  0
# Remains of wildlife collected?             0
# Remains of wildlife sent to Smithsonian    0
# Remarks                                    0
# Wildlife: Size                             0
# Conditions: Sky                            0
# Wildlife: Species                          0
# ...

# %%
df1.describe()
# Out:
#            Record ID  Wildlife: Number Struck Actual  Number of people injured
# count   25558.000000                    25558.000000              25558.000000
# mean   253916.085609                        2.691525                  0.001056
# std     38510.453382                       12.793975                  0.050420
# min      1195.000000                        1.000000                  0.000000
# 25%    225783.750000                        1.000000                  0.000000
# 50%    248749.000000                        1.000000                  0.000000
# 75%    269168.750000                        1.000000                  0.000000
# max    321909.000000                      942.000000                  6.000000

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25558 entries, 0 to 25557
# Data columns (total 26 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Record ID                                25558 non-null  int64
#  1   Aircraft: Type                           25558 non-null  object
#  2   Airport: Name                            25558 non-null  object
#  3   Altitude bin                             25558 non-null  object
#  4   Aircraft: Make/Model                     25558 non-null  object
#  5   Wildlife: Number struck                  25558 non-null  object
#  6   Wildlife: Number Struck Actual           25558 non-null  int64
#  7   Effect: Impact to flight                 25558 non-null  object
#  8   FlightDate                               25558 non-null  object
#  9   Effect: Indicated Damage                 25558 non-null  object
# ...

# %%
df1.keys()
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Remarks', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?'],
#       dtype='object')

# %%
plt.figure(figsize=(16,9))
ax1=sns.countplot(data=df1,x='Effect: Impact to flight')

for bars in ax1.containers:
    ax1.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax2=sns.countplot(data=df1,x='Wildlife: Size')

for bars in ax2.containers:
    ax2.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax3=sns.countplot(data=df1,x='Number of people injured')

for bars in ax3.containers:
    ax3.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax4=sns.countplot(data=df1,x='Pilot warned of birds or wildlife?')

for bars in ax4.containers:
    ax4.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax5=sns.countplot(data=df1,x='Wildlife: Number struck')

for bars in ax5.containers:
    ax5.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax6=sns.countplot(data=df1,x='Effect: Indicated Damage')

for bars in ax6.containers:
    ax6.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax6=sns.countplot(data=df1,x='Aircraft: Type')

for bars in ax6.containers:
    ax6.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax7=sns.countplot(data=df1,x='When: Phase of flight')

for bars in ax7.containers:
    ax7.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax8=sns.countplot(data=df1,x='Conditions: Precipitation')

for bars in ax8.containers:
    ax8.bar_label(bars)

# %%
df1['Aircraft: Make/Model'].unique()
# Out:
# array(['B-737-400', 'MD-80', 'C-500', 'CL-RJ100/200', 'A-300',
#        'LEARJET-25', 'A-320', 'DC-9-30', 'A-330', 'FOKKER F100', 'C-421',
#        'C-560', 'B-737-200', 'DC-9-50', 'B-737', 'B-737-300', 'SAAB-340',
#        'MD-82', 'HAWKER 800', 'FOKKER F28 MK 1000', 'B-757-200',
#        'EMB-135', 'DC-9-40', 'B-727-200', 'DC-10-30', 'DC-9-10',
#        'EMB-145', 'B-747-1/200', 'B-52H', 'DC-9', 'B-737-500',
#        'B-737-700', 'B-747-400', 'BE-58  BARON', 'B-767-300', 'DC-10',
#        'PA-31 NAVAJO', 'B-727', 'C-172', 'BA-31 JETSTR', 'LEARJET-35',
#        'MD-88', 'BE-1900', 'IAI-1124', 'LEARJET-31', 'C-402',
#        'SHORTS SC7', 'B-737-800', 'A-319', 'CITATION II', 'ATR-72',
#        'DA-20 FALCON', 'BE-400 BJET', 'DA-2000', 'HAWKER-SDLY HS125',
#        'B-767', 'HAWKER 1000', 'PA-28', 'BE-23 SUNDOWNER', 'BELL-206',
#        'DHC8 DASH 8', 'BE-90  KING', 'B-767-200', 'BA-146',
#        'GULFAERO III', 'BE-300 KING', 'MU2', 'DORNIER', 'BE-200 KING',
# ...

# %%
plt.figure(figsize=(16,9))
ax9=sns.countplot(data=df1,x='Remains of wildlife sent to Smithsonian')

for bars in ax9.containers:
    ax9.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax10=sns.countplot(data=df1,x='Remains of wildlife collected?')

for bars in ax10.containers:
    ax10.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax11=sns.countplot(data=df1,x='Conditions: Sky')

for bars in ax11.containers:
    ax11.bar_label(bars)

# %%
df1.keys()
# Out:
# Index(['Record ID', 'Aircraft: Type', 'Airport: Name', 'Altitude bin',
#        'Aircraft: Make/Model', 'Wildlife: Number struck',
#        'Wildlife: Number Struck Actual', 'Effect: Impact to flight',
#        'FlightDate', 'Effect: Indicated Damage',
#        'Aircraft: Number of engines?', 'Aircraft: Airline/Operator',
#        'Origin State', 'When: Phase of flight', 'Conditions: Precipitation',
#        'Remains of wildlife collected?',
#        'Remains of wildlife sent to Smithsonian', 'Remarks', 'Wildlife: Size',
#        'Conditions: Sky', 'Wildlife: Species',
#        'Pilot warned of birds or wildlife?', 'Cost: Total $',
#        'Feet above ground', 'Number of people injured', 'Is Aircraft Large?'],
#       dtype='object')

# %%
plt.figure(figsize=(16,9))
ax13=sns.countplot(data=df1,x='Wildlife: Size',hue='Pilot warned of birds or wildlife?')

for bars in ax13.containers:
    ax13.bar_label(bars)

# %%
plt.figure(figsize=(16,9))
ax14=sns.countplot(data=df1,x='Conditions: Sky',hue='Pilot warned of birds or wildlife?')

for bars in ax14.containers:
    ax14.bar_label(bars)
