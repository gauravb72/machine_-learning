# %% [markdown]
# # importing libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # reading csv file

# %%
df=pd.read_csv("E:\\ineuron internships\\credit_card.csv")
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# ...

# %% [markdown]
# # importing libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.keys()
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %% [raw]
# ID: ID of each client
# LIMIT_BAL: Amount of given credit in NT dollars (includes individual and family/supplementary credit
# SEX: Gender (1=male, 2=female)
# EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
# MARRIAGE: Marital status (1=married, 2=single, 3=others)
# AGE: Age in years
# PAY_0: Repayment status in September, 2005 (-1=pay duly, 1=payment delay for one month, 2=payment delay for two months, … 8=payment delay for eight months, 9=payment delay for nine months and above)
# PAY_2: Repayment status in August, 2005 (scale same as above)
# PAY_3: Repayment status in July, 2005 (scale same as above)
# PAY_4: Repayment status in June, 2005 (scale same as above)
# PAY_5: Repayment status in May, 2005 (scale same as above)
# PAY_6: Repayment status in April, 2005 (scale same as above)
# BILL_AMT1: Amount of bill statement in September, 2005 (NT dollar)
# BILL_AMT2: Amount of bill statement in August, 2005 (NT dollar)
# BILL_AMT3: Amount of bill statement in July, 2005 (NT dollar)
# BILL_AMT4: Amount of bill statement in June, 2005 (NT dollar)
# BILL_AMT5: Amount of bill statement in May, 2005 (NT dollar)
# BILL_AMT6: Amount of bill statement in April, 2005 (NT dollar)
# PAY_AMT1: Amount of previous payment in September, 2005 (NT dollar)
# PAY_AMT2: Amount of previous payment in August, 2005 (NT dollar)
# PAY_AMT3: Amount of previous payment in July, 2005 (NT dollar)
# PAY_AMT4: Amount of previous payment in June, 2005 (NT dollar)
# PAY_AMT5: Amount of previous payment in May, 2005 (NT dollar)
# PAY_AMT6: Amount of previous payment in April, 2005 (NT dollar)
# default.payment.next.month: Default payment (1=yes, 0=no)

# %%
plt.figure(figsize=(16,9))
ax1=sns.countplot(data=df,x='AGE')


for bars in ax1.containers:
    ax1.bar_label(bars)
    
    
plt.show()

# %%
plt.figure(figsize=(16,9))
ax2=sns.countplot(data=df,x='SEX')


for bars in ax2.containers:
    ax2.bar_label(bars)
    
    
plt.show()

# %%
df['LIMIT_BAL'].min()
# Out:
# 10000.0

# %%
df['LIMIT_BAL'].max()
# Out:
# 1000000.0

# %%
plt.figure(figsize=(16,9))
ax2=sns.countplot(data=df,x='MARRIAGE')


for bars in ax2.containers:
    ax2.bar_label(bars)
    
    
plt.show()

# %%
plt.figure(figsize=(16,9))
ax3=sns.countplot(data=df,x='EDUCATION')


for bars in ax3.containers:
    ax3.bar_label(bars)
    
    
plt.show()

# %%
plt.figure(figsize=(16,9))
ax4=sns.countplot(data=df,x='default.payment.next.month')


for bars in ax4.containers:
    ax4.bar_label(bars)
    
    
plt.show()

# %%
plt.figure(figsize=(16,9))
ax5=sns.countplot(data=df,x='PAY_0')


for bars in ax5.containers:
    ax5.bar_label(bars)
    
    
plt.show()

# %%
#Repayment status in august 2005
plt.figure(figsize=(16,9))
ax6=sns.countplot(data=df,x='PAY_2')


for bars in ax6.containers:
    ax6.bar_label(bars)
    
    
plt.show()

# %%
#Repayment status in july 2005
plt.figure(figsize=(16,9))
ax7=sns.countplot(data=df,x='PAY_3')


for bars in ax7.containers:
    ax7.bar_label(bars)
    
    
plt.show()

# %%
#Repayment status in june 2005
plt.figure(figsize=(16,9))
ax8=sns.countplot(data=df,x='PAY_4')


for bars in ax8.containers:
    ax8.bar_label(bars)
    
    
plt.show()

# %%
#Repayment status in may 2005
plt.figure(figsize=(16,9))
ax9=sns.countplot(data=df,x='PAY_5')


for bars in ax9.containers:
    ax9.bar_label(bars)
    
    
plt.show()

# %%
#Repayment status in april 2005
plt.figure(figsize=(16,9))
ax10=sns.countplot(data=df,x='PAY_6')


for bars in ax10.containers:
    ax10.bar_label(bars)
    
    
plt.show()

# %%
plt.figure(figsize=(16,9))
ax11=sns.countplot(data=df,x='default.payment.next.month',hue='SEX')


for bars in ax11.containers:
    ax11.bar_label(bars)
    
    
plt.show()

# %%
plt.figure(figsize=(16,9))
ax12=sns.countplot(data=df,x='default.payment.next.month',hue='MARRIAGE')


for bars in ax12.containers:
    ax12.bar_label(bars)
    
    
plt.show()

# %%
X=df.drop('default.payment.next.month',axis=1)
y=df['default.payment.next.month']

# %% [markdown]
# # importing scikit learn libraries

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=51)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train,y_train)
lr.score(X_test,y_test)
# Out:
# 0.13106467739044847

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(X_train,y_train)
dt.score(X_test,y_test)
# Out:
# 0.7201666666666666

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier(n_estimators=110)
rf.fit(X_train,y_train)
rf.score(X_test,y_test)
# Out:
# 0.8183333333333334

# %%
rf1=RandomForestClassifier()
rf1.fit(X_train,y_train)
rf1.score(X_test,y_test)
# Out:
# 0.822

# %%
rf1.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
y_test
# Out:
# 15153    1
# 20107    0
# 20840    0
# 19668    0
# 1821     0
#         ..
# 10553    1
# 13171    0
# 18361    0
# 4227     0
# 25301    0
# Name: default.payment.next.month, Length: 6000, dtype: int64

# %% [markdown]
# # Randomforest algorithm gives 82% accuracy

# %% [markdown]
# # conclusion
# 1) MOre people are of 29 age
# 2) Numbers of female > numbers of male(1=male,2=female)
# 3) Minimum credit given = 10000 dollars
#    Maximum credit given = 1000000 dollars
# 4) Single people > Married people > other people(1=married,2=single,3=others)
# 5) University > graduate > high school > unknown > others (1=graduate,2=university,3=high school,4=others,5 & 6=unknowm
# 6) Defaulter no > yes (0=no,1=yes)
# 7) Number of people pay on time are more than who pay early followed by pay delay by 1 month,2 month, 3 month.......
# 8) Most number of defaulter are female than male.
# 9) Maximum number of defaulter are single > married
